# %% [markdown]
# <a href="https://colab.research.google.com/github/hiseverone/Python-Learning/blob/main/01-Python-Basics/python-basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("durga")
# Out:
# durga

# %%
print("durga and Hema")
# Out:
# durga and Hema

# %%
#variable - a store of information

# %%
name = "durga"
age = 22
salary = 27000

print(name)
print(age)
print(salary)
# Out:
# durga
# 22
# 27000

# %%
# Data type - there are 4 type of data type
name = "durga" # string (str)
age = 25 # integer (int)
salary = 27000.00 # decimal (float)
working = True # boolen (bool)

print(type(name))
print(type(age))
print(type(salary))
print(type(working))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#operators
 print(a+b) # add
 print (a-b)#sub
 print(a*b)#multi
 print(a/b)#div
 print(a%b) # modulus/ remainder
 print(a//b) # floor div
 print(a**b)# power

# %%
salary = 30000
pf = 2400
tax = 1500

net_salary=salary-pf-tax
print(net_salary)
# Out:
# 26100

# %%
name = "Hema"
age = 23
city = "ooty"
salary = 25000.00
print(name)
print(age)
print(city)
print(salary)
# Out:
# Hema
# 23
# ooty
# 25000.0

# %%
salary = 30000
PF = 1800
Tax = 500
Netsalary = salary - PF - tax
print(Netsalary)
# Out:
# 26700

# %%
a = 1500
b = 200

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a//b)
print(a**b)
print(a%b)

# %%
name = input("Enter your name: ")
gender =input("Enter your gender: ")
city = input("Enter your city: ")
address = input("Enter your address: ")
place = input("Enter your place: ")

print(name)
print(gender)
print(city)
print(address)
print(place)

# %%
name = input("enter employee name")
salary = int(input("enter employee salary"))
PF = int(input("enter the PF"))
other deduction = int(input("enter the other deduction"))
net_salary = salary - PF - other deduction


print(net_salary)
